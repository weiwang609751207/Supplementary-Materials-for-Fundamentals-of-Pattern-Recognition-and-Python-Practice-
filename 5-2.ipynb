# %%
# %load 5-2.py
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.datasets import make_classification
from sklearn.metrics import mean_squared_error, log_loss, accuracy_score

# ÉèÖÃËæ»úÖÖ×ÓÒÔÈ·±£½á¹û¿ÉÖØÏÖ
np.random.seed(42)

n_samples = 50
X = np.linspace(0, 10, n_samples)
y = np.sin(X) + np.random.normal(0, 0.3, n_samples) # ÕæÊµ¹ØÏµÊÇsin(x)¼ÓÉÏÒ»Ð©ÔëÉù

# »®·ÖÑµÁ·¼¯ºÍ²âÊÔ¼¯
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# ÎªÁËÄ£ÐÍÐèÒª£¬½«X´ÓÒ»Î¬Êý×é×ª»»Îª¶þÎ¬Êý×é£¨sklearnÒªÇó£©
X_train = X_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)

# ¿ÉÊÓ»¯Êý¾Ý
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, s=50, alpha=0.7, label='Training Data', c='blue')
plt.scatter(X_test, y_test, s=50, alpha=0.7, label='Test Data', c='orange')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.title('Generated Non-Linear Data with Noise')
plt.show()

poly_degree = 15
model_no_reg = Pipeline([
    ('poly', PolynomialFeatures(degree=poly_degree, include_bias=False)),
    ('scaler', StandardScaler()), # 正则化前标准化至关重要！
    ('linear', LinearRegression())
])
# ¶¨ÒåÄ£ÐÍ¹ÜµÀ£¬Ê¹ÓÃRidge´úÌæLinearRegression
# alpha ¾ÍÊÇÕýÔò»¯Ç¿¶È ¦Ë
model_ridge = Pipeline([
    ('poly', PolynomialFeatures(degree=poly_degree, include_bias=False)),
    ('scaler', StandardScaler()),
    ('ridge', Ridge(alpha=1.0)) # ÉèÖÃÒ»¸ö³õÊ¼µÄalphaÖµ
])

# ÑµÁ·Ä£ÐÍ
model_ridge.fit(X_train, y_train)

# Ô¤²âºÍÆÀ¹À
y_train_pred_ridge = model_ridge.predict(X_train)
y_test_pred_ridge = model_ridge.predict(X_test)
train_mse_ridge = mean_squared_error(y_train, y_train_pred_ridge)
test_mse_ridge = mean_squared_error(y_test, y_test_pred_ridge)
print(f"Ridge (L2) - Train MSE: {train_mse_ridge:.4f}, Test MSE: {test_mse_ridge:.4f}")

# »æÖÆÄâºÏÇúÏß
X_plot = np.linspace(0, 10, 100).reshape(-1, 1)
y_plot_pred = model_no_reg.predict(X_plot)
y_plot_pred_ridge = model_ridge.predict(X_plot)

plt.figure(figsize=(12, 8))
plt.scatter(X_train, y_train, s=50, alpha=0.7, label='Training Data')
plt.scatter(X_test, y_test, s=50, alpha=0.7, label='Test Data')
plt.plot(X_plot, y_plot_pred, 'r-', label='No Reg (Overfit)', linewidth=2, alpha=0.5)
plt.plot(X_plot, y_plot_pred_ridge, 'g--', label='Ridge (L2 Regularization)', linewidth=3)
plt.ylim(-2, 2)
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.title(f'Ridge Regression (L2) Effect\nTrain MSE: {train_mse_ridge:.4f}, Test MSE: {test_mse_ridge:.4f}')
plt.show()
# Out:
# Ridge (L2) - Train MSE: 0.3069, Test MSE: 0.2489
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# File ~\anaconda3\envs\pattern_recognition\lib\site-packages\sklearn\pipeline.py:54, in _raise_or_warn_if_not_fitted(estimator)
#      53 try:
# ---> 54     yield
#      55 except NotFittedError as exc:
#
# File ~\anaconda3\envs\pattern_recognition\lib\site-packages\sklearn\pipeline.py:787, in Pipeline.predict(self, X, **params)
#     786 for _, name, transform in self._iter(with_final=False):
# --> 787     Xt = transform.transform(Xt)
#     788 return self.steps[-1][1].predict(Xt, **params)
#
# File ~\anaconda3\envs\pattern_recognition\lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
# ...
